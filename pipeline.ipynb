# %%
from sklearn import set_config
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import StandardScaler, PowerTransformer, OrdinalEncoder
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv', index_col='PassengerId')
df['Personal_Title'] = df.Name.str.extract('.*, (.+?).', expand=False)
df = df.drop(columns={'Name', 'Ticket', 'Cabin', 'Fare'}).dropna()

df_fet = df.drop(columns='Survived')
target = df['Survived']

df_fet.head()
# Out:
#              Pclass     Sex   Age  SibSp  Parch Embarked Personal_Title
# PassengerId
# 1                 3    male  22.0      1      0        S              M
# 2                 1  female  38.0      1      0        C              M
# 3                 3  female  26.0      0      0        S              M
# 4                 1  female  35.0      1      0        S              M
# 5                 3    male  35.0      0      0        S              M

# %%
num_fet = df_fet.select_dtypes('number').columns
str_fet = df_fet.select_dtypes(exclude='number').columns

print(num_fet)
print(str_fet)
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch'], dtype='object')
# Index(['Sex', 'Embarked', 'Personal_Title'], dtype='object')

# %%
prepo_pipeline = make_column_transformer(
    [make_pipeline(PowerTransformer(), StandardScaler()), num_fet],
    [OrdinalEncoder(), str_fet]
)

prepo_pipeline
# Out:
# ColumnTransformer(transformers=[('pipeline',
#                                  Pipeline(steps=[('powertransformer',
#                                                   PowerTransformer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Pclass', 'Age', 'SibSp', 'Parch'], dtype='object')),
#                                 ('ordinalencoder', OrdinalEncoder(),
#                                  Index(['Sex', 'Embarked', 'Personal_Title'], dtype='object'))])

# %%
prepo_pipeline.fit(df_fet)
# Out:
# ColumnTransformer(transformers=[('pipeline',
#                                  Pipeline(steps=[('powertransformer',
#                                                   PowerTransformer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Pclass', 'Age', 'SibSp', 'Parch'], dtype='object')),
#                                 ('ordinalencoder', OrdinalEncoder(),
#                                  Index(['Sex', 'Embarked', 'Personal_Title'], dtype='object'))])

# %%
pd.DataFrame(
    data=prepo_pipeline.transform(df_fet),
    columns=prepo_pipeline.get_feature_names_out()

)
# Out:
#      pipeline__Pclass  pipeline__Age  pipeline__SibSp  pipeline__Parch  \
# 0            0.940654      -0.469528         1.290366        -0.609138
# 1           -1.409998       0.609720         1.290366        -0.609138
# 2            0.940654      -0.186239        -0.716478        -0.609138
# 3           -1.409998       0.417070         1.290366        -0.609138
# 4            0.940654       0.417070        -0.716478        -0.609138
# ..                ...            ...              ...              ...
# 707          0.940654       0.673133        -0.716478         1.785665
# 708         -0.430593      -0.117045        -0.716478        -0.609138
# 709         -1.409998      -0.689838        -0.716478        -0.609138
# 710         -1.409998      -0.186239        -0.716478        -0.609138
# 711          0.940654       0.220509        -0.716478        -0.609138
#
#      ordinalencoder__Sex  ordinalencoder__Embarked  \
# 0                    1.0                       2.0
# ...
